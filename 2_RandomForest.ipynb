# %% [markdown]
# # *Developing a function for the Random Forest Algorithm and applying dataset to this model*

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# Mounting Google Drive to access the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading data from csv file
dataset = pd.read_csv('/content/drive/MyDrive/ML_2023/processed_dataset.csv')

# %% [markdown]
# Creating a function to buld and train the ML Model

# %%
x = pd.DataFrame(dataset.iloc[:, 0:4].values)
y = dataset.iloc[:, 4].values

# %%
import time

# %%
#Generating training and test data sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 123)

# %%
# Importing Random Forest

from sklearn.ensemble import RandomForestRegressor

RFreg = RandomForestRegressor(n_estimators = 10, random_state = 0)
start_time = time.time()
RFreg.fit(x_train,y_train)
end_time = time.time()
fit_time = end_time - start_time
print("Fit Time:", fit_time, "seconds")
# Out:
# Fit Time: 0.891301471710205 seconds

# %%
start_time = time.time()
y_pred = RFreg.predict(x_test)
end_time = time.time()
prediction_time = end_time - start_time

# %%
# Prediction Metrics

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


MSE = mse(y_test, y_pred)
R2 = r2_score(y_test, y_pred)
MAX_ERROR = max_error(y_test, y_pred);
MEAN_ABSOLUTE_ERROR = mean_absolute_error(y_test, y_pred)
MAPE = mean_absolute_percentage_error(y_test, y_pred)


print("Mean Squared Error", MSE)
print("R-Squared: ", R2)
print("Max Error", MAX_ERROR);
print("Mean Absolute Error", MEAN_ABSOLUTE_ERROR);
print("MAPE", MAPE);
# Out:
# Mean Squared Error 3.8164402183723376
# R-Squared:  0.8264125804237101
# Max Error 28.459232751900004
# Mean Absolute Error 0.8615421950396005
# MAPE 0.09427826288072323

# %%
print("Prediction Time:", prediction_time, "seconds")
# Out:
# Prediction Time: 0.05803325843811035 seconds

# %% [markdown]
# Create a function that will plot a graph between the predicted and actual values

# %%
import matplotlib.pyplot as plt
plt.scatter(x=y_test, y=y_pred, c='crimson', alpha=0.6)
plt.plot(y_pred, y_pred,color='black', linestyle='dashed')
plt.title('Actual vs. Predicted Values of Return Loss (Random Forest)')
plt.xlabel('Actual values (dB)')
plt.ylabel('Predicted values (dB)')
plt.show()
